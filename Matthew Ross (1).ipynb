# %%
import pandas as pd
import numpy as np

# %%
routes_data = pd.read_csv("Routes.csv")

# %%
routes_data.head()
# Out:
#   route ridership_route_code    route_full_name current_garage mode  \
# 0     1                  001  1 - FREEPORT ROAD           Ross  Bus
# 1     1                  001  1 - FREEPORT ROAD           Ross  Bus
# 2     1                  001  1 - FREEPORT ROAD           Ross  Bus
# 3     2                  002    2 - MOUNT ROYAL           Ross  Bus
# 4     4                  004      4 - TROY HILL           Ross  Bus
#
#   month_start  year_month day_type  on_time_percent data_source
# 0  2017-01-01      201701  WEEKDAY           0.6837         UTA
# 1  2017-01-01      201701     SAT.           0.6977         UTA
# 2  2017-01-01      201701     SUN.           0.6280         UTA
# 3  2017-01-01      201701  WEEKDAY           0.6978         UTA
# 4  2017-01-01      201701  WEEKDAY           0.7438         UTA

# %%
not_on_time_routes = routes_data[routes_data["on_time_percent"] < .8].index
on_time_routes = routes_data.drop(not_on_time_routes)
on_time_routes.head(10)
# Out:
#     route ridership_route_code    route_full_name current_garage mode  \
# 6       6                  006    6 - SPRING HILL           Ross  Bus
# 26     15                  015       15 - CHARLES           Ross  Bus
# 46     26                  026     26 - CHARTIERS        Collier  Bus
# 47     26                  026     26 - CHARTIERS        Collier  Bus
# 49     27                  027     27 - FAIRYWOOD        Collier  Bus
# 68     41                  041    41 - BOWER HILL        Collier  Bus
# 89     55                  055     55 - GLASSPORT   West Mifflin  Bus
# 90     55                  055     55 - GLASSPORT   West Mifflin  Bus
# 151    78                  078       78 - OAKMONT   East Liberty  Bus
# 162    83                  083  83 - BEDFORD HILL   West Mifflin  Bus
#
#     month_start  year_month day_type  on_time_percent data_source
# 6    2017-01-01      201701  WEEKDAY           0.8049         UTA
# ...

# %%
unique_routes = routes_data['route'].unique()
for x inroutes_data:
# Out:
# ['1' '2' '4' '6' '7' '8' '11' '12' '13' '14' '15' '16' '17' '18' '19L'
#  '20' '21' '22' '24' '26' '27' '28X' '29' '31' '36' '38' '39' '40' '41'
#  '43' '44' '48' '51' '51L' '52L' '53' '53L' '54' '55' '56' '57' '58' '59'
#  '60' '61A' '61B' '61C' '61D' '64' '65' '67' '68' '69' '71' '71A' '71B'
#  '71C' '71D' '74' '75' '77' '78' '79' '81' '82' '83' '86' '87' '88' '89'
#  '91' '93' 'G2' 'G3' 'G31' 'O1' 'O12' 'O5' 'P1' 'P10' 'P12' 'P13' 'P16'
#  'P17' 'P2' 'P3' 'P67' 'P68' 'P69' 'P7' 'P71' 'P76' 'P78' 'Y1' 'Y45' 'Y46'
#  'Y47' 'Y49' 'BLLB' 'BLSV' 'RED' 'BLUE' 'SLVR' nan]

# %%
routes_data.boxplot(column="on_time_percent", by="route", figsize=(30,10))

# %% [markdown]
# For further work, we will be filtering out routes that have low averages, trying to find the ones most consistently on-time. P17, 74, and 82 are the main routes in Lincoln-Lemington-Belmar. 74 and 82 have good on-time percentages, but P17 does not - on further analysis, this may cause us to revise our choice of neighborhood.
